# %% [markdown]
# # Explore Your Dataset With Python and Pandas

# %% [markdown]
# This notebook contains the examples of the Real Python tutorial [Explore Your Dataset With Python and Pandas](https://realpython.com/explore-your-dataset-python-pandas/)

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# ### Hello Pandas

# %%
import requests
download_url = "https://raw.githubusercontent.com/fivethirtyeight/data/master/nba-elo/nbaallelo.csv"
csv_path = "nba_all_elo.csv"

response = requests.get(download_url)
with open(csv_path,"wb") as f:
    f.write(response.content)
print("Download ready.")
# Out:
# Download ready.

# %%
import pandas as pd

nba = pd.read_csv(csv_path)
len(nba)
# Out:
# 126314

# %%
nba.shape
# Out:
# (126314, 23)

# %%
nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
pd.set_option("display.precision", 2)

# %%
nba.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
nba.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311      60.01    GSW   Warriors      104    1809.98    1813.63
# 126312      59.29    GSW   Warriors      105    1813.63    1822.29
# 126313      68.52    CLE  Cavaliers       97    1700.74    1692.09
#
#        game_location game_result  forecast notes
# 126311             A           L      0.23   NaN
# ...

# %% [markdown]
# ## Getting to Know Your Data

# %% [markdown]
# ### Displaying Data Types With `.info()`

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null object
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# elo_i            126314 non-null float64
# elo_n            126314 non-null float64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# opp_elo_i        126314 non-null float64
# opp_elo_n        126314 non-null float64
# game_location    126314 non-null object
# game_result      126314 non-null object
# ...

# %% [markdown]
# ### Showing Basics Statistics With `.describe()`

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
import numpy as np
nba.describe(include=np.object)
# Out:
#              game_id   lg_id  date_game team_id fran_id  opp_id opp_fran  \
# count         126314  126314     126314  126314  126314  126314   126314
# unique         63157       2      12426     104      53     104       53
# top     200011210IND     NBA  4/13/2011     BOS  Lakers     BOS   Lakers
# freq               2  118016         30    5997    6024    5997     6024
#
#        game_location game_result           notes
# count         126314      126314            5424
# unique             3           2             231
# top                A           L  at New York NY
# freq           63138       63157             440

# %% [markdown]
# ### A Mini Data Exploration With Pandas

# %%
nba["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
# CHI    4307
# PHO    4080
# ATL    4035
# MIL    4034
# POR    3870
# HOU    3820
# CLE    3810
# GSW    3701
# SEA    3547
# SAS    3515
# IND    3364
# DEN    3312
# UTA    3145
# DAL    3013
# NJN    2939
# LAC    2563
# SAC    2488
# MIA    2371
# ORL    2207
# MIN    2131
# WSB    1992
# TOR    1634
# WAS    1475
# CIN    1230
# MEM    1197
#        ...
# OAK     172
# PTC     168
# NOP     168
# MMT     168
# PRO     168
# NOK     164
# HSM     159
# TRI     135
# WSA      91
# MMS      89
# CAP      89
# TEX      89
# MNM      88
# MNP      85
# NYN      82
# CHO      82
# CHP      80
# CHZ      80
# NJA      78
# ANA      78
# AND      72
# SHE      65
# CLR      63
# DNN      62
# WAT      62
# DTF      60
# INJ      60
# PIT      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
nba["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
nba[nba["fran_id"] == "Lakers"]["team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
nba[nba["team_id"] == "MNL"]["date_game"].min()
# Out:
# '1/1/1949'

# %%
nba[nba["team_id"] == "MNL"]["date_game"].max()
# Out:
# '4/9/1959'

# %%
nba[nba["team_id"] == "BOS"]["pts"].sum()
# Out:
# 626484

# %% [markdown]
# ## Getting to Know Pandas' Data Structures

# %% [markdown]
# ### `Series`: The Basic Building Block in Pandas

# %% [markdown]
# Series with only an implicit index

# %%
revenues = pd.Series([5555, 7000, 1980])
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.values
# Out:
# array([5555, 7000, 1980])

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
type(revenues.values)
# Out:
# numpy.ndarray

# %% [markdown]
# Series with positional and label index:

# %%
city_revenues = pd.Series(
    [4200, 8000, 6500],
    index=["Amsterdam", "Toronto", "Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %% [markdown]
# ### `Pandas Series` vs Built-In Python Data Structures

# %%
# Creating a Series based on a dict
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
"New York" in city_employee_count
# Out:
# False

# %% [markdown]
# ### `DataFrame`: Pandas' Most Popular Data Structure

# %%
city_data = pd.DataFrame({
    "revenue": city_revenues, 
    "employee_count": city_employee_count
})
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
"Amsterdam" in city_data
# Out:
# False

# %%
"revenue" in city_data
# Out:
# True

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
"points" in nba.keys()
# Out:
# False

# %%
"pts" in nba.keys()
# Out:
# True

# %% [markdown]
# ##  Accessing Elements for Python `list`s and Pandas `Series`: Similarities and Differences

# %% [markdown]
# ### The Benefits and Limitations of the Python Indexing Operator `[]`

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues["Toronto"]
# Out:
# 8000

# %%
city_revenues[1]
# Out:
# 8000

# %%
city_revenues[-1]
# Out:
# 6500

# %%
city_revenues[1:]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
city_revenues["Toronto":]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %% [markdown]
# ### Accessing `Series`' Elements via `.loc` and `.iloc`

# %%
colors = pd.Series(
    ["red", "purple", "blue", "green", "yellow"], 
    index=[1, 2, 3, 5, 8]
)
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.loc[1]
# Out:
# 'red'

# %%
colors.iloc[1]
# Out:
# 'purple'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.loc[3:8]
# Out:
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.iloc[-2]
# Out:
# 'green'

# %% [markdown]
# ## Accessing the Elements of a `DataFrame`

# %% [markdown]
# ### Accessing a `DataFrame`s Columns

# %%
city_data["revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
type(city_data["revenue"])
# Out:
# pandas.core.series.Series

# %%
city_data.revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: revenue, dtype: int64

# %%
toys = toys = pd.DataFrame([
    {"name": "ball", "shape": "sphere"},
    {"name": "Rubik's cube", "shape": "cube"}
])
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %% [markdown]
# ### Accessing a `DataFrame`'s Rows With `.loc` and `.iloc`

# %%
city_data.loc["Amsterdam"]
# Out:
# revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.loc["Tokyo": "Toronto"]
# Out:
#          revenue  employee_count
# Tokyo       6500             8.0
# Toronto     8000             NaN

# %%
city_data.iloc[1]
# Out:
# revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %%
nba.iloc[-2]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           6/16/2015
# seasongame                102
# is_playoffs                 1
# team_id                   CLE
# fran_id             Cavaliers
# pts                        97
# elo_i                 1.7e+03
# elo_n                 1.7e+03
# win_equiv                  59
# opp_id                    GSW
# opp_fran             Warriors
# opp_pts                   105
# opp_elo_i             1.8e+03
# opp_elo_n             1.8e+03
# game_location               H
# game_result                 L
# forecast                 0.48
# notes                     NaN
# Name: 126312, dtype: object

# %% [markdown]
# ### Accessing a Subset of Rows and Columns in a `DataFrame` With `.loc` and `.iloc`

# %%
city_data.loc["Amsterdam": "Tokyo", "revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Name: revenue, dtype: int64

# %%
nba.loc[5555:5559, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#       fran_id  opp_fran  pts  opp_pts
# 5555  Pistons  Warriors   83       56
# 5556  Celtics    Knicks   95       74
# 5557   Knicks   Celtics   74       95
# 5558    Kings    Sixers   81       86
# 5559   Sixers     Kings   86       81

# %% [markdown]
# ## Queries with Pandas

# %%
current_decade = nba[nba["year_id"] > 2010]
current_decade.shape
# Out:
# (12658, 23)

# %%
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# 113661      56831  201010260POR   NBA        0     2011  10/26/2010
# 113662      56832  201010270CLE   NBA        0     2011  10/27/2010
# 113663      56832  201010270CLE   NBA        1     2011  10/27/2010
# 113664      56833  201010270DAL   NBA        1     2011  10/27/2010
# 113665      56833  201010270DAL   NBA        0     2011  10/27/2010
# 113666      56834  201010270DEN   NBA        0     2011  10/27/2010
# 113667      56834  201010270DEN   NBA        1     2011  10/27/2010
# 113668      56835  201010270GSW   NBA        0     2011  10/27/2010
# ...

# %%
ers = nba[nba["fran_id"].str.endswith("ers")]
ers.shape
# Out:
# (27797, 23)

# %%
ers
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 7               4  194611020PRO   NBA        0     1947   11/2/1946
# 9               5  194611020STB   NBA        0     1947   11/2/1946
# 16              9  194611050DTF   NBA        1     1947   11/5/1946
# 20             11  194611070PRO   NBA        0     1947   11/7/1946
# 22             12  194611070STB   NBA        0     1947   11/7/1946
# 30             16  194611090PRO   NBA        0     1947   11/9/1946
# 32             17  194611090STB   NBA        0     1947   11/9/1946
# 39             20  194611110PIT   NBA        1     1947  11/11/1946
# 43             22  194611130DTF   NBA        1     1947  11/13/1946
# 47             24  194611140STB   NBA        0     1947  11/14/1946
# 48             25  194611150TRH   NBA        1     1947  11/15/1946
# 57             29  194611160PRO   NBA        0     1947  11/16/1946
# 58             30  194611160STB   NBA        0     1947  11/16/1946
# ...

# %%
games_with_notes = nba[nba["notes"].notnull()]
games_with_notes.shape
# Out:
# (5424, 23)

# %%
nba[
    (nba["_iscopy"] == 0) & 
    (nba["pts"] > 100) & 
    (nba["opp_pts"] > 100) & 
    (nba["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 1726            0     BLB  Baltimore  114  1421.94  1419.43      38.56    MNL
# 4890            0     BLB  Baltimore  126  1328.67  1356.65      25.80    BOS
# 4909            0     BLB  Baltimore  104  1349.83  1346.36      24.88    MNL
# 5208            0     BLB  Baltimore  107  1284.52  1282.24      19.58    NYK
# 5825            0     BLB  Baltimore  110  1303.75  1301.97      20.74    BOS
#
# ...

# %%
nba[
    (nba["_iscopy"] == 0) & 
    (nba["team_id"].str.startswith("LA")) & 
    (nba["year_id"]==1992) & 
    (nba["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  pts    elo_i   elo_n  win_equiv opp_id  \
# 68901            1     LAC  Clippers  115  1546.90  1556.0      47.89    UTA
# 68903            1     LAL    Lakers   76  1489.65  1474.4      39.40    POR
#
#            opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# 68901          Jazz      107    1647.51    1638.41             H           W
# 68903  Trailblazers      102    1655.12    1670.37             H           L
#
#        forecast                                       notes
# 68901      0.50  at Anaheim, CA (Anaheim Convention Center)
# 68903      0.41                            at Las Vegas, NV

# %% [markdown]
# ## Aggregations

# %% [markdown]
# ### Aggregations for `Series`

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues.max()
# Out:
# 8000

# %% [markdown]
# ### Aggregations for `DataFrame`

# %%
points = nba["pts"]
type(points)
# Out:
# pandas.core.series.Series

# %%
points.sum()
# Out:
# 12976235

# %% [markdown]
# ### Grouping

# %%
nba.groupby("fran_id", sort=False)["pts"].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
nba[
    (nba["fran_id"] == "Spurs") & 
    (nba["year_id"] > 2010)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %%
nba[
    (nba["fran_id"] == "Warriors") & 
    (nba["year_id"] == 2015)
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %% [markdown]
# ## Manipulating Columns

# %%
df = nba.copy()

# %% [markdown]
# ### Adding New Columns

# %%
df["difference"] = df.pts - df.opp_pts
df.shape
# Out:
# (126314, 24)

# %%
df["difference"].max()
# Out:
# 68

# %% [markdown]
# ### Renaming Columns

# %%
renamed_df = df.rename(
    columns={"game_result": "result", "game_location": "location"}
)
renamed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 24 columns):
# gameorder      126314 non-null int64
# game_id        126314 non-null object
# lg_id          126314 non-null object
# _iscopy        126314 non-null int64
# year_id        126314 non-null int64
# date_game      126314 non-null object
# seasongame     126314 non-null int64
# is_playoffs    126314 non-null int64
# team_id        126314 non-null object
# fran_id        126314 non-null object
# pts            126314 non-null int64
# elo_i          126314 non-null float64
# elo_n          126314 non-null float64
# win_equiv      126314 non-null float64
# opp_id         126314 non-null object
# opp_fran       126314 non-null object
# opp_pts        126314 non-null int64
# opp_elo_i      126314 non-null float64
# opp_elo_n      126314 non-null float64
# location       126314 non-null object
# result         126314 non-null object
# forecast       126314 non-null float64
# ...

# %% [markdown]
# ### Deleting Columns

# %%
elo_columns = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]
df.drop(elo_columns, inplace=True, axis=1)
df.shape
# Out:
# (126314, 20)

# %% [markdown]
# ### Changing The Data Type of Columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null object
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# game_location    126314 non-null object
# game_result      126314 non-null object
# forecast         126314 non-null float64
# notes            5424 non-null object
# difference       126314 non-null int64
# dtypes: float64(2), int64(8), object(10)
# ...

# %%
df["date_game"] = pd.to_datetime(df["date_game"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null datetime64[ns]
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# game_location    126314 non-null object
# game_result      126314 non-null object
# forecast         126314 non-null float64
# notes            5424 non-null object
# difference       126314 non-null int64
# ...

# %%
df["game_location"].nunique()
# Out:
# 3

# %%
df["game_location"].value_counts()
# Out:
# A    63138
# H    63138
# N       38
# Name: game_location, dtype: int64

# %%
df["game_location"] = pd.Categorical(df["game_location"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null datetime64[ns]
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# game_location    126314 non-null category
# game_result      126314 non-null object
# forecast         126314 non-null float64
# notes            5424 non-null object
# difference       126314 non-null int64
# ...

# %%
df["game_result"].nunique()
# Out:
# 2

# %%
df["game_result"].value_counts()
# Out:
# L    63157
# W    63157
# Name: game_result, dtype: int64

# %%
df["game_result"] = pd.Categorical(df["game_result"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
# gameorder        126314 non-null int64
# game_id          126314 non-null object
# lg_id            126314 non-null object
# _iscopy          126314 non-null int64
# year_id          126314 non-null int64
# date_game        126314 non-null datetime64[ns]
# seasongame       126314 non-null int64
# is_playoffs      126314 non-null int64
# team_id          126314 non-null object
# fran_id          126314 non-null object
# pts              126314 non-null int64
# win_equiv        126314 non-null float64
# opp_id           126314 non-null object
# opp_fran         126314 non-null object
# opp_pts          126314 non-null int64
# game_location    126314 non-null category
# game_result      126314 non-null category
# forecast         126314 non-null float64
# notes            5424 non-null object
# difference       126314 non-null int64
# ...

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Missing Values

# %%
rows_without_missing_data = nba.dropna()
rows_without_missing_data.shape
# Out:
# (5424, 23)

# %%
data_without_missing_columns = nba.dropna(axis=1)
data_without_missing_columns.shape
# Out:
# (126314, 22)

# %%
data_with_default_notes = nba.copy()
data_with_default_notes["notes"].fillna(
    value="no notes at all",
    inplace=True
)
data_with_default_notes["notes"].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %% [markdown]
# ### Invalid Values

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 26684      13343  197210260VIR   ABA        1     1973  10/26/1972
#
#        seasongame  is_playoffs team_id  fran_id  pts    elo_i    elo_n  \
# 26684           7            0     DNR  Nuggets    0  1460.34  1457.45
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 26684      40.41    VIR  Squires        2    1484.19    1487.08             A
#
#       game_result  forecast                           notes
# 26684           L      0.33  at Richmond VA; forfeit to VIR

# %% [markdown]
# ### Inconsistencies Between Values in Different Columns

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes]
# Index: []

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba["game_result"] != 'L')]
# Out:
# Empty DataFrame
# Columns: [gameorder, game_id, lg_id, _iscopy, year_id, date_game, seasongame, is_playoffs, team_id, fran_id, pts, elo_i, elo_n, win_equiv, opp_id, opp_fran, opp_pts, opp_elo_i, opp_elo_n, game_location, game_result, forecast, notes]
# Index: []

# %% [markdown]
# ## Detecting Connections With `.corr()` in Pandas

# %%
nba.corr()
# Out:
#              gameorder   _iscopy   year_id  seasongame  is_playoffs   pts  \
# gameorder     1.00e+00  0.00e+00  9.89e-01    4.35e-02     3.67e-03 -0.19
# _iscopy       0.00e+00  1.00e+00  0.00e+00    4.06e-04     0.00e+00 -0.13
# year_id       9.89e-01  0.00e+00  1.00e+00    3.72e-02    -3.85e-03 -0.12
# seasongame    4.35e-02  4.06e-04  3.72e-02    1.00e+00     4.45e-01  0.06
# is_playoffs   3.67e-03  0.00e+00 -3.85e-03    4.45e-01     1.00e+00 -0.04
# pts          -1.87e-01 -1.26e-01 -1.24e-01    6.19e-02    -3.94e-02  1.00
# elo_i         1.31e-01  1.66e-03  1.26e-01    1.10e-01     2.25e-01  0.09
# elo_n         1.30e-01  1.51e-03  1.26e-01    1.10e-01     2.25e-01  0.12
# win_equiv     1.12e-02  1.51e-03  9.22e-03    1.11e-01     2.37e-01  0.14
# opp_pts      -1.87e-01  1.26e-01 -1.24e-01    6.27e-02    -3.94e-02  0.59
# opp_elo_i     1.31e-01 -1.66e-03  1.26e-01    1.12e-01     2.25e-01 -0.15
# opp_elo_n     1.30e-01 -1.51e-03  1.26e-01    1.11e-01     2.25e-01 -0.18
# ...

# %% [markdown]
# ## Working With Multiple Datasets in Pandas
#
# ### Combining Data Based on The Index With `concat()``

# %%
further_city_data = pd.DataFrame(
    {"revenue": [7000, 3400], "employee_count":[2, 2]},
    index=["New York", "Barcelona"]
)
all_city_data = pd.concat([city_data, further_city_data], sort=False)
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1, 1, 0, 0, 0]},
    index=["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"]
)
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %% [markdown]
# ### Combining Data Based on Arbitrary Columns With `merge()`

# %%
countries = pd.DataFrame({
    "population_millions": [17, 127, 37],
    "continent": ["Europe", "Asia", "North America"]
},
    index= ["Holland", "Japan", "Canada"]
)
pd.merge(cities, countries, left_on="country", right_index=True)
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
pd.merge(cities, countries, left_on="country", right_index=True, how="left")
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %% [markdown]
# ## Visualizing Your Pandas DataFrame

# %%
# %matplotlib inline
nba[(nba["fran_id"] == "Knicks")].groupby("year_id")["pts"].sum().plot()

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")

# %%
nba[
    (nba["fran_id"] == "Heat") & 
    (nba["year_id"] == 2013)
]["game_result"].value_counts().plot(kind="pie")
